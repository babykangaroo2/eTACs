# %%
# Loading libraries
import pandas as pd

# %%
# Loading datafile
immgen = pd.read_csv('/Users/andersonlab/ImmGen_Complete.csv')
immgen

# %%
# Post averaging and clean up in R
immgen_cleaned = pd.read_csv('/Users/andersonlab/eTACs/ImmGen_Averaged.csv')
immgen_cleaned
# Out:
#        Unnamed: 0           Gene  X.SC_LTSL_BM.  X.SC_STSL_BM.  X.SC_LTSL_FL.  \
# 0               1  0610007C21Rik      258.82100       354.1960      366.13100
# 1               2  0610007L01Rik      301.69750       310.1445      310.69850
# 2               3  0610007P08Rik      161.22950       175.3555      182.91100
# 3               4  0610007P14Rik      429.40600       439.8140      388.79500
# 4               5  0610007P22Rik      120.68600       167.8375      141.15650
# 5               6  0610008F07Rik       50.19910        44.3538       50.20770
# 6               7  0610009B22Rik       75.62150        94.2428       80.63030
# 7               8  0610009D07Rik       85.73130       119.0080      103.77600
# 8               9  0610009L18Rik      286.92800       233.3510      216.56800
# 9              10  0610009O20Rik      244.46700       270.1210      242.18300
# 10             11  0610010F05Rik      130.25200       139.0270      160.67100
# ...

# %%
#x = pd.sort(immgen_cleaned,'X.SC_LTSL_BM.')
x = immgen_cleaned.sort_values(['X.SC_LTSL_BM.'], ascending=[0])

# %%
x.T.loc['Gene']
# Out:
# 11024        LOC236598
# 16692            Rn18s
# 4658              COX1
# 5138              CYTB
# 16693            Rn7sk
# 12749              ND5
# 1642              Actb
# 6029            Eef1a1
# 12746              ND2
# 8093           Gm15427
# 14654           Pabpc1
# 2764          AY036118
# 2659              ATP6
# 12748             ND4L
# 4666              COX2
# 2804               B2m
# 7657           Gm10293
# 9413          Hist1h3b
# 9436          Hist2h3b
# 16866           Rpl18a
# 17097           S100a9
# 16870        Rpl21-ps4
# 8578            Gm9104
# 9419          Hist1h3h
# 7329             Gapdh
# 9414          Hist1h3c
# 8345            Gm5523
# 9420          Hist1h3i
# 9412          Hist1h3a
# 9418          Hist1h3g
#              ...
# 20669         Vmn1r201
# 7647           Gm10267
# 13432         Olfr1049
# 17419        Serpinb3a
# 10997     LOC100503047
# 11966           Mir463
# 13689          Olfr134
# 8419            Gm6133
# 13604         Olfr1251
# ...
